# %% [markdown]
# ## Data Analysis

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ROLLBACK
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
import libs
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import yfinance as yf
import duckdb as ddb

import io
from urllib.request import urlopen
import zipfile
import os

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///../../eda-ddb/eda-yfinance.ddb

# %%
# %sql SELECT count(*) from yfinance
# Out:
#    count_star()
# 0         37704

# %%
# %sql SELECT * FROM yfinance LIMIT 1;
# Out:
#       Open       High        Low  Close  Adj Close     Volume Sector Stock  \
# 0  38.7225  39.712502  38.557499  39.48   37.75008  148158800   tech  AAPL
#
#         Date
# 0 2019-01-02

# %%
# %%sql
# select *
# from INFORMATION_SCHEMA.COLUMNS
# where TABLE_NAME='yfinance'
# Out:
#   table_catalog table_schema table_name column_name  ordinal_position  \
# 0  eda-yfinance         main   yfinance        Open                 1
# 1  eda-yfinance         main   yfinance        High                 2
# 2  eda-yfinance         main   yfinance         Low                 3
# 3  eda-yfinance         main   yfinance       Close                 4
# 4  eda-yfinance         main   yfinance   Adj Close                 5
# 5  eda-yfinance         main   yfinance      Volume                 6
# 6  eda-yfinance         main   yfinance      Sector                 7
# 7  eda-yfinance         main   yfinance       Stock                 8
# 8  eda-yfinance         main   yfinance        Date                 9
#
#   column_default is_nullable     data_type  character_maximum_length  \
# 0           None         YES        DOUBLE                       NaN
# 1           None         YES        DOUBLE                       NaN
# ...

# %%
# %%sql
# SELECT DISTINCT Stock FROM yfinance
# Out:
#    Stock
# 0    ADM
# 1    JNJ
# 2    NEM
# 3     DE
# 4    COP
# 5     MA
# 6     KO
# 7   MSFT
# 8      V
# 9    DOW
# 10   FCX
# 11  NVDA
# 12  AAPL
# 13  CTVA
# 14   XOM
# 15   JPM
# 16   CVX
# 17   PEP
# 18     T
# 19    VZ
# 20    PG
# 21  ABBV
# 22    BP
# 23   PFE
# 24  TMUS

# %%
# %%sql
# select *
# from INFORMATION_SCHEMA.COLUMNS
# where TABLE_NAME='yfinance'
# Out:
#   table_catalog table_schema table_name column_name  ordinal_position  \
# 0  eda-yfinance         main   yfinance        Open                 1
# 1  eda-yfinance         main   yfinance        High                 2
# 2  eda-yfinance         main   yfinance         Low                 3
# 3  eda-yfinance         main   yfinance       Close                 4
# 4  eda-yfinance         main   yfinance   Adj Close                 5
# 5  eda-yfinance         main   yfinance      Volume                 6
# 6  eda-yfinance         main   yfinance      Sector                 7
# 7  eda-yfinance         main   yfinance       Stock                 8
# 8  eda-yfinance         main   yfinance        Date                 9
#
#   column_default is_nullable     data_type  character_maximum_length  \
# 0           None         YES        DOUBLE                       NaN
# 1           None         YES        DOUBLE                       NaN
# ...

# %%
# %%sql
# SELECT * FROM yfinance LIMIT 1;
# Out:
#       Open       High        Low  Close  Adj Close     Volume Sector Stock  \
# 0  38.7225  39.712502  38.557499  39.48   37.75008  148158800   tech  AAPL
#
#         Date
# 0 2019-01-02
