# %%
! pip install plotly --quiet
! pip install pyarrow --quiet

import duckdb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px
from statsmodels.tsa.stattools import grangercausalitytests

# %%
con_gdelt = duckdb.connect('eda-ddb/eda-gdelt.ddb')
print(con_gdelt.execute("SELECT * FROM gdelt LIMIT 1").fetch_df().columns)
con_gdelt.close()

con_yfinance = duckdb.connect('eda-ddb/eda-yfinance.ddb')
print(con_yfinance.execute("SELECT * FROM yfinance LIMIT 1").fetch_df().columns)
con_yfinance.close()
# Out:
# Index(['GlobalEventID', 'Day', 'MonthYear', 'Year', 'FractionDate',
#        'Actor1Code', 'Actor1Name', 'Actor1CountryCode', 'Actor1KnownGroupCode',
#        'Actor2Code', 'Actor2Name', 'Actor2CountryCode', 'Actor2KnownGroupCode',
#        'IsRootEvent', 'EventCode', 'EventBaseCode', 'EventRootCode',
#        'QuadClass', 'GoldsteinScale', 'NumMentions', 'NumSources',
#        'NumArticles', 'AvgTone', 'Actor1Geo_Type', 'Actor1Geo_CountryCode',
#        'Actor2Geo_Type', 'Actor2Geo_CountryCode', 'ActionGeo_Type',
#        'ActionGeo_CountryCode', 'SOURCEURL'],
#       dtype='object')
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Sector',
#        'Stock', 'Date'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# # Question 3
# What is the average delay in an event happening and the consequences/effect on the stock market (if any)?

# %% [markdown]
# ---

# %% [markdown]
# # 2019

# %% [markdown]
# ## Monthly

# %%
# Connect to DuckDB (create a single connection)
con_gdelt = duckdb.connect('eda-ddb/eda-gdelt.ddb')

# Load and aggregate GDELT data by month for 2019
gdelt_monthly_df = con_gdelt.execute("""
    SELECT 
        STRFTIME(STRPTIME(CAST(Day AS VARCHAR), '%Y%m%d'), '%Y-%m') AS Month,
        COUNT(GlobalEventID) AS EventCount,
        AVG(AvgTone) AS AvgTone
    FROM gdelt
    WHERE STRPTIME(CAST(Day AS VARCHAR), '%Y%m%d') BETWEEN '2019-01-01' AND '2019-12-31'
    GROUP BY Month
""").fetch_df()

# Close the GDELT connection
con_gdelt.close()

# %%
# Connect to Yahoo Finance database
con_yfinance = duckdb.connect('eda-ddb/eda-yfinance.ddb')

# Load and aggregate Yahoo Finance data by month for 2019
yfinance_monthly_df = con_yfinance.execute("""
    SELECT 
        STRFTIME(Date, '%Y-%m') AS Month,
        Stock,
        Sector,
        AVG(Close) AS AvgClose
    FROM yfinance 
    WHERE Date BETWEEN '2019-01-01' AND '2019-12-31'
    GROUP BY Month, Stock, Sector
""").fetch_df()


# Close the Yahoo Finance connection
con_yfinance.close()

# %%
merged_monthly_df = pd.merge(gdelt_monthly_df, yfinance_monthly_df, on='Month', how='inner')
merged_monthly_df['Month'] = pd.to_datetime(merged_monthly_df['Month'])

# %% [markdown]
# ### Time-Series Plot of Events and Stock Prices Monthly

# %%
# Group by sector then find the average close price for each month
sector_avg_close_df = merged_monthly_df.groupby(['Month', 'Sector'], as_index=False).agg(
    {'AvgClose': 'mean', 'EventCount': 'sum'}
)
sector_avg_close_df
# Out:
#         Month       Sector    AvgClose  EventCount
# 0  2019-01-01  agriculture  100.262619     9487062
# 1  2019-01-01       energy   72.409762    18974124
# 2  2019-01-01      finance  145.137937    14230593
# 3  2019-01-01         food   83.045079    14230593
# 4  2019-01-01       health   84.916431    14230593
# ..        ...          ...         ...         ...
# 91 2019-12-01         food  105.325079    12083499
# 92 2019-12-01       health   89.172952    12083499
# 93 2019-12-01    materials   35.779524    12083499
# 94 2019-12-01         tech   76.309083    12083499
# 95 2019-12-01      telecom   55.637311    12083499
#
# [96 rows x 4 columns]

# %%
# Create subplots with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Define unique sectors for color separation
sectors = sector_avg_close_df['Sector'].unique()

# Create a color palette to assign different colors to each sector
colors = {
    sector: color
    for sector, color in zip(sectors, px.colors.qualitative.Set1)
}

# Add traces for each sector for AvgClose (primary y-axis)
for sector in sectors:
    sector_data = sector_avg_close_df[sector_avg_close_df['Sector'] == sector]
    
    # Plot AvgClose for the sector
    fig.add_trace(
        go.Scatter(
            x=sector_data['Month'], 
            y=sector_data['AvgClose'], 
            mode='lines+markers',
            name=f'{sector} AvgClose',
            line=dict(color=colors[sector]),
        ),
        secondary_y=False  # Primary y-axis
    )

    # Plot EventCount for the sector (secondary y-axis)
    fig.add_trace(
        go.Scatter(
            x=sector_data['Month'], 
            y=sector_data['EventCount'], 
            mode='lines+markers',
            name=f'{sector} EventCount',
            line=dict(dash='dot', color=colors[sector]),  # Dashed line for EventCount
        ),
        secondary_y=True  # Secondary y-axis
    )

# Update y-axis titles
fig.update_yaxes(title_text="AvgClose (Stock Price)", secondary_y=False)
fig.update_yaxes(title_text="EventCount", secondary_y=True)

# Update x-axis title and overall title
fig.update_layout(
    autosize=False,
    width=1200,
    height=800,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
    title_text="Average Close Price and Event Count by Sector",
    xaxis_title="Month",
    legend_title="Sector",
)

# Show the plot
fig.show()

# %% [markdown]
# ### Testing the Hypotheses

# %% [markdown]
# #### Granger Causality Test

# %% [markdown]
# Then apply a Granger causality test to assess whether past values of EventCount can predict AvgClose changes.

# %%
data_lag = merged_monthly_df[['EventCount', 'AvgClose']].dropna()
granger_test_result = grangercausalitytests(data_lag, maxlag=5, verbose=True)
p_values = {lag: test[0]['ssr_ftest'][1] for lag, test in granger_test_result.items()}
p_values_df = pd.DataFrame(p_values.items(), columns=['Lag', 'p-value'])
top_5_results = p_values_df.sort_values(by='p-value')
top_5_results
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2836  , p=0.2582  , df_denom=290, df_num=1
# ssr based chi2 test:   chi2=1.2969  , p=0.2548  , df=1
# likelihood ratio test: chi2=1.2940  , p=0.2553  , df=1
# parameter F test:         F=1.2836  , p=0.2582  , df_denom=290, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2741  , p=0.2813  , df_denom=287, df_num=2
# ssr based chi2 test:   chi2=2.5926  , p=0.2735  , df=2
# likelihood ratio test: chi2=2.5811  , p=0.2751  , df=2
# parameter F test:         F=1.2741  , p=0.2813  , df_denom=287, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1258  , p=0.3389  , df_denom=284, df_num=3
# ssr based chi2 test:   chi2=3.4605  , p=0.3259  , df=3
# likelihood ratio test: chi2=3.4401  , p=0.3286  , df=3
# parameter F test:         F=1.1258  , p=0.3389  , df_denom=284, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9699  , p=0.4243  , df_denom=281, df_num=4
# ssr based chi2 test:   chi2=4.0038  , p=0.4055  , df=4
# likelihood ratio test: chi2=3.9764  , p=0.4092  , df=4
# parameter F test:         F=0.9699  , p=0.4243  , df_denom=281, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7881  , p=0.5590  , df_denom=278, df_num=5
# ssr based chi2 test:   chi2=4.0965  , p=0.5356  , df=5
# likelihood ratio test: chi2=4.0677  , p=0.5397  , df=5
# parameter F test:         F=0.7881  , p=0.5590  , df_denom=278, df_num=5
# C:\Users\lklin\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning:
#
# verbose is deprecated since functions should not print results
#    Lag   p-value
# 0    1  0.258166
# 1    2  0.281264
# 2    3  0.338938
# 3    4  0.424346
# 4    5  0.558967

# %%
data_lag = merged_monthly_df[['AvgClose', 'EventCount']].dropna()
granger_test_result = grangercausalitytests(data_lag, maxlag=5, verbose=True)
p_values = {lag: test[0]['ssr_ftest'][1] for lag, test in granger_test_result.items()}
p_values_df = pd.DataFrame(p_values.items(), columns=['Lag', 'p-value'])
top_5_results = p_values_df.sort_values(by='p-value')
top_5_results
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5788  , p=0.4474  , df_denom=290, df_num=1
# ssr based chi2 test:   chi2=0.5848  , p=0.4445  , df=1
# likelihood ratio test: chi2=0.5842  , p=0.4447  , df=1
# parameter F test:         F=0.5788  , p=0.4474  , df_denom=290, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6376  , p=0.5293  , df_denom=287, df_num=2
# ssr based chi2 test:   chi2=1.2973  , p=0.5227  , df=2
# likelihood ratio test: chi2=1.2944  , p=0.5235  , df=2
# parameter F test:         F=0.6376  , p=0.5293  , df_denom=287, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5418  , p=0.2039  , df_denom=284, df_num=3
# ssr based chi2 test:   chi2=4.7393  , p=0.1919  , df=3
# likelihood ratio test: chi2=4.7011  , p=0.1950  , df=3
# parameter F test:         F=1.5418  , p=0.2039  , df_denom=284, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.6314  , p=0.0346  , df_denom=281, df_num=4
# ssr based chi2 test:   chi2=10.8628 , p=0.0282  , df=4
# likelihood ratio test: chi2=10.6642 , p=0.0306  , df=4
# parameter F test:         F=2.6314  , p=0.0346  , df_denom=281, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3338  , p=0.0425  , df_denom=278, df_num=5
# ssr based chi2 test:   chi2=12.1306 , p=0.0330  , df=5
# likelihood ratio test: chi2=11.8829 , p=0.0364  , df=5
# parameter F test:         F=2.3338  , p=0.0425  , df_denom=278, df_num=5
# C:\Users\lklin\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning:
#
# verbose is deprecated since functions should not print results
#    Lag   p-value
# 3    4  0.034637
# 4    5  0.042453
# 2    3  0.203877
# 0    1  0.447414
# 1    2  0.529332

# %% [markdown]
# ## Daily

# %%
# Connect to DuckDB (create a single connection)
con_gdelt = duckdb.connect('eda-ddb/eda-gdelt.ddb')

# Load and aggregate GDELT data by day for 2019
gdelt_daily_df = con_gdelt.execute("""
    SELECT 
        STRFTIME(STRPTIME(CAST(Day AS VARCHAR), '%Y%m%d'), '%Y-%m-%d') AS Day,
        COUNT(GlobalEventID) AS EventCount,
        AVG(AvgTone) AS AvgTone
    FROM gdelt
    WHERE STRPTIME(CAST(Day AS VARCHAR), '%Y%m%d') BETWEEN '2019-01-01' AND '2019-12-31'
    GROUP BY Day
""").fetch_df()

# Close the GDELT connection
con_gdelt.close()

# %%
# Connect to Yahoo Finance database
con_yfinance = duckdb.connect('eda-ddb/eda-yfinance.ddb')

# Load and aggregate Yahoo Finance data by day for 2019
yfinance_daily_df = con_yfinance.execute("""
    SELECT 
        STRFTIME(Date, '%Y-%m-%d') AS Day,
        Stock,
        Sector,
        AVG(Close) AS AvgClose
    FROM yfinance 
    WHERE Date BETWEEN '2019-01-01' AND '2019-12-31'
    GROUP BY Day, Stock, Sector
""").fetch_df()

# Close the Yahoo Finance connection
con_yfinance.close()

# %%
merged_daily_df = pd.merge(gdelt_daily_df, yfinance_daily_df, on='Day', how='inner')
merged_daily_df['Day'] = pd.to_datetime(merged_daily_df['Day'])

# %% [markdown]
# ### Time-Series Plot of Events and Stock Prices Daily

# %%
# Group by sector then find the average close price for each day
sector_avg_close_daily_df = merged_daily_df.groupby(['Day', 'Sector'], as_index=False).agg(
    {'AvgClose': 'mean', 'EventCount': 'sum'}
)

# %%
# Create subplots with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Define unique sectors for color separation
sectors = sector_avg_close_daily_df['Sector'].unique()

# Create a color palette to assign different colors to each sector
colors = {
    sector: color
    for sector, color in zip(sectors, px.colors.qualitative.Set1)
}

# Add traces for each sector for AvgClose (primary y-axis)
for sector in sectors:
    sector_data = sector_avg_close_daily_df[sector_avg_close_daily_df['Sector'] == sector]
    
    # Plot AvgClose for the sector
    fig.add_trace(
        go.Scatter(
            x=sector_data['Day'], 
            y=sector_data['AvgClose'], 
            mode='lines+markers',
            name=f'{sector} AvgClose',
            line=dict(color=colors[sector]),
        ),
        secondary_y=False  # Primary y-axis
    )

    # Plot EventCount for the sector (secondary y-axis)
    fig.add_trace(
        go.Scatter(
            x=sector_data['Day'], 
            y=sector_data['EventCount'], 
            mode='lines+markers',
            name=f'{sector} EventCount',
            line=dict(dash='dot', color=colors[sector]),  # Dashed line for EventCount
        ),
        secondary_y=True  # Secondary y-axis
    )

# Update y-axis titles
fig.update_yaxes(title_text="AvgClose (Stock Price)", secondary_y=False)
fig.update_yaxes(title_text="EventCount", secondary_y=True)

# Update x-axis title and overall title
fig.update_layout(
    autosize=False,
    width=1400,
    height=800,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
    title_text="Average Close Price and Event Count by Sector",
    xaxis_title="Month",
    legend_title="Sector",
)

# Show the plot
fig.show()

# %% [markdown]
# ### Testing the Hypothesis

# %% [markdown]
# #### Granger Causality Test

# %%
data_lag = merged_daily_df[['EventCount', 'AvgClose']].dropna()
granger_test_result = grangercausalitytests(data_lag, maxlag=30, verbose=True)
# print(granger_test_result)

p_values = {lag: test[0]['ssr_ftest'][1] for lag, test in granger_test_result.items()}
p_values_df = pd.DataFrame(p_values.items(), columns=['Lag', 'p-value'])
top_5_results = p_values_df.sort_values(by='p-value').head(5)
print(top_5_results)

# p_values = {lag: test[0]['ssr_ftest'][1] for lag, test in granger_test_result.items()}
# p_values_df = pd.DataFrame(p_values.items(), columns=['Lag', 'p-value'])
# significant_lags = p_values_df[p_values_df['p-value'] < 0.05].sort_values(by='p-value')
# if not significant_lags.empty:
#     first_significant_lag = significant_lags.iloc[0]
#     print(f"The first lag with p-value < 0.05 is Lag {first_significant_lag['Lag']} with p-value {first_significant_lag['p-value']:.4f}.")
# else:
#     print("No significant lags found with p-value < 0.05.")
# Out:
# C:\Users\lklin\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning:
#
# verbose is deprecated since functions should not print results
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.2447  , p=0.0717  , df_denom=6144, df_num=1
# ssr based chi2 test:   chi2=3.2463  , p=0.0716  , df=1
# likelihood ratio test: chi2=3.2454  , p=0.0716  , df=1
# parameter F test:         F=3.2447  , p=0.0717  , df_denom=6144, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6310  , p=0.1958  , df_denom=6141, df_num=2
# ssr based chi2 test:   chi2=3.2646  , p=0.1955  , df=2
# likelihood ratio test: chi2=3.2638  , p=0.1956  , df=2
# parameter F test:         F=1.6310  , p=0.1958  , df_denom=6141, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6957  , p=0.0443  , df_denom=6138, df_num=3
# ssr based chi2 test:   chi2=8.0962  , p=0.0441  , df=3
# likelihood ratio test: chi2=8.0909  , p=0.0442  , df=3
# parameter F test:         F=2.6957  , p=0.0443  , df_denom=6138, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.9704  , p=0.0183  , df_denom=6135, df_num=4
# ssr based chi2 test:   chi2=11.8990 , p=0.0181  , df=4
# likelihood ratio test: chi2=11.8874 , p=0.0182  , df=4
# parameter F test:         F=2.9704  , p=0.0183  , df_denom=6135, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.0093  , p=0.0102  , df_denom=6132, df_num=5
# ssr based chi2 test:   chi2=15.0737 , p=0.0101  , df=5
# likelihood ratio test: chi2=15.0553 , p=0.0101  , df=5
# parameter F test:         F=3.0093  , p=0.0102  , df_denom=6132, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4991  , p=0.0204  , df_denom=6129, df_num=6
# ssr based chi2 test:   chi2=15.0267 , p=0.0201  , df=6
# likelihood ratio test: chi2=15.0083 , p=0.0202  , df=6
# parameter F test:         F=2.4991  , p=0.0204  , df_denom=6129, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1358  , p=0.0368  , df_denom=6126, df_num=7
# ssr based chi2 test:   chi2=14.9873 , p=0.0362  , df=7
# likelihood ratio test: chi2=14.9691 , p=0.0364  , df=7
# parameter F test:         F=2.1358  , p=0.0368  , df_denom=6126, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.2625  , p=0.0206  , df_denom=6123, df_num=8
# ssr based chi2 test:   chi2=18.1505 , p=0.0201  , df=8
# likelihood ratio test: chi2=18.1238 , p=0.0203  , df=8
# parameter F test:         F=2.2625  , p=0.0206  , df_denom=6123, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0432  , p=0.0311  , df_denom=6120, df_num=9
# ssr based chi2 test:   chi2=18.4463 , p=0.0303  , df=9
# likelihood ratio test: chi2=18.4187 , p=0.0306  , df=9
# parameter F test:         F=2.0432  , p=0.0311  , df_denom=6120, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8241  , p=0.0513  , df_denom=6117, df_num=10
# ssr based chi2 test:   chi2=18.3037 , p=0.0501  , df=10
# likelihood ratio test: chi2=18.2764 , p=0.0505  , df=10
# parameter F test:         F=1.8241  , p=0.0513  , df_denom=6117, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.6377  , p=0.0816  , df_denom=6114, df_num=11
# ssr based chi2 test:   chi2=18.0820 , p=0.0797  , df=11
# likelihood ratio test: chi2=18.0554 , p=0.0803  , df=11
# parameter F test:         F=1.6377  , p=0.0816  , df_denom=6114, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.9945  , p=0.0209  , df_denom=6111, df_num=12
# ssr based chi2 test:   chi2=24.0316 , p=0.0201  , df=12
# likelihood ratio test: chi2=23.9847 , p=0.0204  , df=12
# parameter F test:         F=1.9945  , p=0.0209  , df_denom=6111, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.9418  , p=0.0216  , df_denom=6108, df_num=13
# ssr based chi2 test:   chi2=25.3545 , p=0.0207  , df=13
# likelihood ratio test: chi2=25.3022 , p=0.0211  , df=13
# parameter F test:         F=1.9418  , p=0.0216  , df_denom=6108, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.8144  , p=0.0310  , df_denom=6105, df_num=14
# ssr based chi2 test:   chi2=25.5230 , p=0.0297  , df=14
# likelihood ratio test: chi2=25.4700 , p=0.0302  , df=14
# parameter F test:         F=1.8144  , p=0.0310  , df_denom=6105, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.8190  , p=0.0267  , df_denom=6102, df_num=15
# ssr based chi2 test:   chi2=27.4229 , p=0.0255  , df=15
# likelihood ratio test: chi2=27.3617 , p=0.0259  , df=15
# parameter F test:         F=1.8190  , p=0.0267  , df_denom=6102, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.7938  , p=0.0263  , df_denom=6099, df_num=16
# ssr based chi2 test:   chi2=28.8562 , p=0.0249  , df=16
# likelihood ratio test: chi2=28.7885 , p=0.0254  , df=16
# parameter F test:         F=1.7938  , p=0.0263  , df_denom=6099, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.6963  , p=0.0364  , df_denom=6096, df_num=17
# ssr based chi2 test:   chi2=29.0026 , p=0.0345  , df=17
# likelihood ratio test: chi2=28.9342 , p=0.0351  , df=17
# parameter F test:         F=1.6963  , p=0.0364  , df_denom=6096, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.6180  , p=0.0473  , df_denom=6093, df_num=18
# ssr based chi2 test:   chi2=29.3008 , p=0.0448  , df=18
# likelihood ratio test: chi2=29.2310 , p=0.0456  , df=18
# parameter F test:         F=1.6180  , p=0.0473  , df_denom=6093, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.8957  , p=0.0107  , df_denom=6090, df_num=19
# ssr based chi2 test:   chi2=36.2486 , p=0.0098  , df=19
# likelihood ratio test: chi2=36.1419 , p=0.0101  , df=19
# parameter F test:         F=1.8957  , p=0.0107  , df_denom=6090, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.8133  , p=0.0145  , df_denom=6087, df_num=20
# ssr based chi2 test:   chi2=36.5097 , p=0.0134  , df=20
# likelihood ratio test: chi2=36.4013 , p=0.0138  , df=20
# parameter F test:         F=1.8133  , p=0.0145  , df_denom=6087, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.7907  , p=0.0146  , df_denom=6084, df_num=21
# ssr based chi2 test:   chi2=37.8695 , p=0.0133  , df=21
# likelihood ratio test: chi2=37.7530 , p=0.0138  , df=21
# parameter F test:         F=1.7907  , p=0.0146  , df_denom=6084, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.6886  , p=0.0231  , df_denom=6081, df_num=22
# ssr based chi2 test:   chi2=37.4230 , p=0.0212  , df=22
# likelihood ratio test: chi2=37.3092 , p=0.0219  , df=22
# parameter F test:         F=1.6886  , p=0.0231  , df_denom=6081, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.6618  , p=0.0244  , df_denom=6078, df_num=23
# ssr based chi2 test:   chi2=38.5164 , p=0.0224  , df=23
# likelihood ratio test: chi2=38.3958 , p=0.0231  , df=23
# parameter F test:         F=1.6618  , p=0.0244  , df_denom=6078, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.6678  , p=0.0216  , df_denom=6075, df_num=24
# ssr based chi2 test:   chi2=40.3490 , p=0.0196  , df=24
# likelihood ratio test: chi2=40.2167 , p=0.0203  , df=24
# parameter F test:         F=1.6678  , p=0.0216  , df_denom=6075, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.6226  , p=0.0259  , df_denom=6072, df_num=25
# ssr based chi2 test:   chi2=40.9051 , p=0.0235  , df=25
# likelihood ratio test: chi2=40.7691 , p=0.0243  , df=25
# parameter F test:         F=1.6226  , p=0.0259  , df_denom=6072, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.3819  , p=0.0937  , df_denom=6069, df_num=26
# ssr based chi2 test:   chi2=36.2421 , p=0.0873  , df=26
# likelihood ratio test: chi2=36.1352 , p=0.0892  , df=26
# parameter F test:         F=1.3819  , p=0.0937  , df_denom=6069, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.3306  , p=0.1176  , df_denom=6066, df_num=27
# ssr based chi2 test:   chi2=36.2515 , p=0.1099  , df=27
# likelihood ratio test: chi2=36.1446 , p=0.1122  , df=27
# parameter F test:         F=1.3306  , p=0.1176  , df_denom=6066, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.2877  , p=0.1420  , df_denom=6063, df_num=28
# ssr based chi2 test:   chi2=36.3940 , p=0.1328  , df=28
# likelihood ratio test: chi2=36.2862 , p=0.1355  , df=28
# parameter F test:         F=1.2877  , p=0.1420  , df_denom=6063, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.4431  , p=0.0586  , df_denom=6060, df_num=29
# ssr based chi2 test:   chi2=42.2561 , p=0.0533  , df=29
# likelihood ratio test: chi2=42.1109 , p=0.0549  , df=29
# parameter F test:         F=1.4431  , p=0.0586  , df_denom=6060, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.4696  , p=0.0474  , df_denom=6057, df_num=30
# ssr based chi2 test:   chi2=44.5315 , p=0.0427  , df=30
# likelihood ratio test: chi2=44.3702 , p=0.0441  , df=30
# parameter F test:         F=1.4696  , p=0.0474  , df_denom=6057, df_num=30
#     Lag   p-value
# 4     5  0.010227
# 18   19  0.010670
# 19   20  0.014525
# 20   21  0.014558
# 3     4  0.018329

# %%
data_lag = merged_daily_df[['AvgClose', 'EventCount']].dropna()
granger_test_result = grangercausalitytests(data_lag, maxlag=30, verbose=True)
# print(granger_test_result)

p_values = {lag: test[0]['ssr_ftest'][1] for lag, test in granger_test_result.items()}
p_values_df = pd.DataFrame(p_values.items(), columns=['Lag', 'p-value'])
top_5_results = p_values_df.sort_values(by='p-value').head(5)
print(top_5_results)

# p_values = {lag: test[0]['ssr_ftest'][1] for lag, test in granger_test_result.items()}
# p_values_df = pd.DataFrame(p_values.items(), columns=['Lag', 'p-value'])
# significant_lags = p_values_df[p_values_df['p-value'] < 0.05].sort_values(by='p-value')
# if not significant_lags.empty:
#     first_significant_lag = significant_lags.iloc[0]
#     print(f"The first lag with p-value < 0.05 is Lag {first_significant_lag['Lag']} with p-value {first_significant_lag['p-value']:.4f}.")
# else:
#     print("No significant lags found with p-value < 0.05.")
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.7101  , p=0.0998  , df_denom=6144, df_num=1
# ssr based chi2 test:   chi2=2.7114  , p=0.0996  , df=1
# likelihood ratio test: chi2=2.7108  , p=0.0997  , df=1
# parameter F test:         F=2.7101  , p=0.0998  , df_denom=6144, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7042  , p=0.1820  , df_denom=6141, df_num=2
# ssr based chi2 test:   chi2=3.4112  , p=0.1817  , df=2
# likelihood ratio test: chi2=3.4102  , p=0.1818  , df=2
# parameter F test:         F=1.7042  , p=0.1820  , df_denom=6141, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3053  , p=0.2708  , df_denom=6138, df_num=3
# ssr based chi2 test:   chi2=3.9203  , p=0.2702  , df=3
# likelihood ratio test: chi2=3.9191  , p=0.2703  , df=3
# parameter F test:         F=1.3053  , p=0.2708  , df_denom=6138, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7100  , p=0.1448  , df_denom=6135, df_num=4
# ssr based chi2 test:   chi2=6.8498  , p=0.1440  , df=4
# likelihood ratio test: chi2=6.8460  , p=0.1443  , df=4
# parameter F test:         F=1.7100  , p=0.1448  , df_denom=6135, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6303  , p=0.0221  , df_denom=6132, df_num=5
# ssr based chi2 test:   chi2=13.1749 , p=0.0218  , df=5
# likelihood ratio test: chi2=13.1608 , p=0.0219  , df=5
# parameter F test:         F=2.6303  , p=0.0221  , df_denom=6132, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3575  , p=0.0282  , df_denom=6129, df_num=6
# ssr based chi2 test:   chi2=14.1748 , p=0.0277  , df=6
# C:\Users\lklin\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning:
#
# verbose is deprecated since functions should not print results
# likelihood ratio test: chi2=14.1584 , p=0.0279  , df=6
# parameter F test:         F=2.3575  , p=0.0282  , df_denom=6129, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9982  , p=0.0516  , df_denom=6126, df_num=7
# ssr based chi2 test:   chi2=14.0218 , p=0.0508  , df=7
# likelihood ratio test: chi2=14.0058 , p=0.0511  , df=7
# parameter F test:         F=1.9982  , p=0.0516  , df_denom=6126, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8977  , p=0.0559  , df_denom=6123, df_num=8
# ssr based chi2 test:   chi2=15.2236 , p=0.0549  , df=8
# likelihood ratio test: chi2=15.2048 , p=0.0553  , df=8
# parameter F test:         F=1.8977  , p=0.0559  , df_denom=6123, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.8207  , p=0.0595  , df_denom=6120, df_num=9
# ssr based chi2 test:   chi2=16.4373 , p=0.0583  , df=9
# likelihood ratio test: chi2=16.4153 , p=0.0587  , df=9
# parameter F test:         F=1.8207  , p=0.0595  , df_denom=6120, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8276  , p=0.0507  , df_denom=6117, df_num=10
# ssr based chi2 test:   chi2=18.3385 , p=0.0495  , df=10
# likelihood ratio test: chi2=18.3112 , p=0.0499  , df=10
# parameter F test:         F=1.8276  , p=0.0507  , df_denom=6117, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.7323  , p=0.0604  , df_denom=6114, df_num=11
# ssr based chi2 test:   chi2=19.1267 , p=0.0589  , df=11
# likelihood ratio test: chi2=19.0970 , p=0.0594  , df=11
# parameter F test:         F=1.7323  , p=0.0604  , df_denom=6114, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.5833  , p=0.0889  , df_denom=6111, df_num=12
# ssr based chi2 test:   chi2=19.0774 , p=0.0867  , df=12
# likelihood ratio test: chi2=19.0478 , p=0.0874  , df=12
# parameter F test:         F=1.5833  , p=0.0889  , df_denom=6111, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.7086  , p=0.0525  , df_denom=6108, df_num=13
# ssr based chi2 test:   chi2=22.3099 , p=0.0507  , df=13
# likelihood ratio test: chi2=22.2694 , p=0.0513  , df=13
# parameter F test:         F=1.7086  , p=0.0525  , df_denom=6108, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.6884  , p=0.0510  , df_denom=6105, df_num=14
# ssr based chi2 test:   chi2=23.7506 , p=0.0491  , df=14
# likelihood ratio test: chi2=23.7047 , p=0.0497  , df=14
# parameter F test:         F=1.6884  , p=0.0510  , df_denom=6105, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.6122  , p=0.0624  , df_denom=6102, df_num=15
# ssr based chi2 test:   chi2=24.3058 , p=0.0601  , df=15
# likelihood ratio test: chi2=24.2577 , p=0.0608  , df=15
# parameter F test:         F=1.6122  , p=0.0624  , df_denom=6102, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.5460  , p=0.0750  , df_denom=6099, df_num=16
# ssr based chi2 test:   chi2=24.8701 , p=0.0721  , df=16
# likelihood ratio test: chi2=24.8198 , p=0.0731  , df=16
# parameter F test:         F=1.5460  , p=0.0750  , df_denom=6099, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.4974  , p=0.0854  , df_denom=6096, df_num=17
# ssr based chi2 test:   chi2=25.6015 , p=0.0820  , df=17
# likelihood ratio test: chi2=25.5482 , p=0.0831  , df=17
# parameter F test:         F=1.4974  , p=0.0854  , df_denom=6096, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.7065  , p=0.0313  , df_denom=6093, df_num=18
# ssr based chi2 test:   chi2=30.9029 , p=0.0295  , df=18
# likelihood ratio test: chi2=30.8253 , p=0.0302  , df=18
# parameter F test:         F=1.7065  , p=0.0313  , df_denom=6093, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.6324  , p=0.0406  , df_denom=6090, df_num=19
# ssr based chi2 test:   chi2=31.2152 , p=0.0382  , df=19
# likelihood ratio test: chi2=31.1359 , p=0.0390  , df=19
# parameter F test:         F=1.6324  , p=0.0406  , df_denom=6090, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.5998  , p=0.0437  , df_denom=6087, df_num=20
# ssr based chi2 test:   chi2=32.2117 , p=0.0411  , df=20
# likelihood ratio test: chi2=32.1274 , p=0.0420  , df=20
# parameter F test:         F=1.5998  , p=0.0437  , df_denom=6087, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.5805  , p=0.0446  , df_denom=6084, df_num=21
# ssr based chi2 test:   chi2=33.4250 , p=0.0417  , df=21
# likelihood ratio test: chi2=33.3342 , p=0.0426  , df=21
# parameter F test:         F=1.5805  , p=0.0446  , df_denom=6084, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.5270  , p=0.0545  , df_denom=6081, df_num=22
# ssr based chi2 test:   chi2=33.8420 , p=0.0510  , df=22
# likelihood ratio test: chi2=33.7489 , p=0.0521  , df=22
# parameter F test:         F=1.5270  , p=0.0545  , df_denom=6081, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.6565  , p=0.0252  , df_denom=6078, df_num=23
# ssr based chi2 test:   chi2=38.3933 , p=0.0231  , df=23
# likelihood ratio test: chi2=38.2735 , p=0.0238  , df=23
# parameter F test:         F=1.6565  , p=0.0252  , df_denom=6078, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.6023  , p=0.0315  , df_denom=6075, df_num=24
# ssr based chi2 test:   chi2=38.7655 , p=0.0289  , df=24
# likelihood ratio test: chi2=38.6433 , p=0.0298  , df=24
# parameter F test:         F=1.6023  , p=0.0315  , df_denom=6075, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.7995  , p=0.0086  , df_denom=6072, df_num=25
# ssr based chi2 test:   chi2=45.3660 , p=0.0076  , df=25
# likelihood ratio test: chi2=45.1987 , p=0.0079  , df=25
# parameter F test:         F=1.7995  , p=0.0086  , df_denom=6072, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.8031  , p=0.0074  , df_denom=6069, df_num=26
# ssr based chi2 test:   chi2=47.2896 , p=0.0065  , df=26
# likelihood ratio test: chi2=47.1079 , p=0.0068  , df=26
# parameter F test:         F=1.8031  , p=0.0074  , df_denom=6069, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.7823  , p=0.0076  , df_denom=6066, df_num=27
# ssr based chi2 test:   chi2=48.5589 , p=0.0066  , df=27
# likelihood ratio test: chi2=48.3673 , p=0.0070  , df=27
# parameter F test:         F=1.7823  , p=0.0076  , df_denom=6066, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.7499  , p=0.0085  , df_denom=6063, df_num=28
# ssr based chi2 test:   chi2=49.4582 , p=0.0074  , df=28
# likelihood ratio test: chi2=49.2594 , p=0.0078  , df=28
# parameter F test:         F=1.7499  , p=0.0085  , df_denom=6063, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.7596  , p=0.0072  , df_denom=6060, df_num=29
# ssr based chi2 test:   chi2=51.5240 , p=0.0062  , df=29
# likelihood ratio test: chi2=51.3083 , p=0.0065  , df=29
# parameter F test:         F=1.7596  , p=0.0072  , df_denom=6060, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.7245  , p=0.0083  , df_denom=6057, df_num=30
# ssr based chi2 test:   chi2=52.2575 , p=0.0071  , df=30
# likelihood ratio test: chi2=52.0356 , p=0.0075  , df=30
# parameter F test:         F=1.7245  , p=0.0083  , df_denom=6057, df_num=30
#     Lag   p-value
# 28   29  0.007163
# 25   26  0.007428
# 26   27  0.007616
# 29   30  0.008335
# 27   28  0.008546

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Summary of Key Findings**
# 1. No Causal Relationship in Monthly Data
#     - p-values > 0.05 across all lags (1, 2, 3)
#     - This means event counts do not significantly predict stock price changes (or vice versa) on a monthly scale
# 2. Significant Causality Found at Daily Level (Lag 22 - 30)
#     - In the daily Granger causality test with 30 lags for serveral times, Lag 22 - 30 was found to have a significant p-value < 0.05. This suggests events have a delayed effect on stock prices after 27 days.
